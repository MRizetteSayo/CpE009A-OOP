# %% [markdown]
# <a href="https://colab.research.google.com/github/MRizetteSayo/CpE009A-OOP/blob/main/Python_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Indentation

# %%
if 5>2:
  print("Five is greater than two")
# Out:
# Five is greater than two

# %% [markdown]
# Python Comments

# %%
#This is a comment
print("Hello, World")
# Out:
# Hello, World
